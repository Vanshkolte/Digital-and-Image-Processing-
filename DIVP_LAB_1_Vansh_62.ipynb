# %% [markdown]
# Name : Vansh Kolte
#
# Roll_no: 62
#
# Practical_1 : DIVP LAB

# %%
import numpy as np
import cv2

# %%
img=cv2.imread('/content/lina.jpg',1) ## Reading an image

# %%
(h,w,d)=img.shape
print('width={},height={},depth={}'.format(w,h,d))
# Out:
# width=512,height=512,depth=3

# %%
# img=cv2.imread('/content/lina.jpg') ##a.Displaying a image in color mode
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#b.Displaying an imagge in gray scale  mode.
from google.colab.patches import cv2_imshow
img1 =cv2.imread('/content/lina.jpg',0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#c.Displaying an imagge in unchange  mode.
from google.colab.patches import cv2_imshow
img2=cv2.imread('/content/lina.jpg',-1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
cv2.imwrite('lenaB&W.png',img1)
cv2.imwrite('lenaColor.png',img)
# Out:
# True

# %%
# img=cv2.imread('/content/lenaColor.png',0)
cv2.rotate(img1,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[ 47,  47,  47, ..., 159, 159, 159],
#        [ 47,  47,  47, ..., 159, 159, 159],
#        [ 48,  48,  48, ..., 159, 159, 159],
#        ...,
#        [106, 104, 101, ..., 170, 168, 167],
#        [106, 104, 102, ..., 151, 150, 151],
#        [105, 104, 101, ..., 129, 129, 130]], dtype=uint8)

# %%
img=cv2.imread('/content/lenaColor.png',0)
cv2.rotate(img,cv2.ROTATE_180)
# Out:
# array([[105, 106, 105, ...,  47,  46,  46],
#        [104, 103, 104, ...,  47,  46,  46],
#        [100, 102, 100, ...,  47,  46,  46],
#        ...,
#        [129, 151, 170, ..., 159, 159, 159],
#        [129, 149, 168, ..., 159, 159, 159],
#        [129, 151, 166, ..., 159, 159, 159]], dtype=uint8)

# %%
img=cv2.imread('/content/lina.jpg',0)
cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
# Out:
# array([[130, 129, 129, ..., 101, 104, 105],
#        [151, 150, 151, ..., 102, 104, 106],
#        [167, 168, 170, ..., 101, 104, 106],
#        ...,
#        [159, 159, 159, ...,  48,  48,  48],
#        [159, 159, 159, ...,  47,  47,  47],
#        [159, 159, 159, ...,  47,  47,  47]], dtype=uint8)

# %%
#resize an image
img=cv2.imread('/content/lenaColor.png',1)
img=cv2.resize(img,(255,255))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=255x255>

# %%
img=cv2.imread('/content/lenaColor.png',0)
_, img_bw=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
cv2_imshow(img_bw)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
img4=cv2.imread('/content/pepper colour.jpg',1) ## Reading an image

# %%
(h,w,d)=img4.shape
print('width={},height={},depth={}'.format(w,h,d))
# Out:
# width=612,height=409,depth=3

# %%
# img3=cv2.imread('/content/pepper colour.jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=612x409>

# %%
#b.Displaying an imagge in gray scale  mode.
from google.colab.patches import cv2_imshow
img5=cv2.imread('/content/pepper colour.jpg',0)
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=L size=612x409>

# %%
cv2.imwrite('BellB&W.png',img5)
cv2.imwrite('BellColor.png',img4)
# Out:
# True

# %%
img5=cv2.imread('/content/pepper colour.jpg',0)
cv2.rotate(img5,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[113, 102,  82, ..., 118, 119, 118],
#        [ 87,  83,  74, ..., 111, 110, 108],
#        [ 89, 105, 108, ..., 106, 106, 106],
#        ...,
#        [ 83,  87,  90, ...,  95, 103, 111],
#        [ 84,  88,  92, ...,  98, 106, 112],
#        [ 84,  89,  93, ..., 100, 108, 114]], dtype=uint8)

# %%
img3=cv2.imread('/content/pepper colour.jpg',0)
cv2.rotate(img3,cv2.ROTATE_180)
# Out:
# array([[ 84,  84,  83, ...,  89,  87, 113],
#        [ 89,  88,  87, ..., 105,  83, 102],
#        [ 93,  92,  90, ..., 108,  74,  82],
#        ...,
#        [100,  98,  95, ..., 106, 111, 118],
#        [108, 106, 103, ..., 106, 110, 119],
#        [114, 112, 111, ..., 106, 108, 118]], dtype=uint8)

# %%
img3=cv2.imread('/content/pepper colour.jpg',0)
cv2.rotate(img3,cv2.ROTATE_90_COUNTERCLOCKWISE)
# Out:
# array([[114, 108, 100, ...,  93,  89,  84],
#        [112, 106,  98, ...,  92,  88,  84],
#        [111, 103,  95, ...,  90,  87,  83],
#        ...,
#        [106, 106, 106, ..., 108, 105,  89],
#        [108, 110, 111, ...,  74,  83,  87],
#        [118, 119, 118, ...,  82, 102, 113]], dtype=uint8)

# %%
img4=cv2.imread('/content/pepper colour.jpg',1)
img4=cv2.resize(img4,(255,255))
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=255x255>

# %%
img4=cv2.imread('/content/pepper colour.jpg',0)
_, img4_bw=cv2.threshold(img4,127,255,cv2.THRESH_BINARY)
cv2_imshow(img4_bw)
# Out:
# <PIL.Image.Image image mode=L size=612x409>
